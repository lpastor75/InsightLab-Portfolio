# %% [markdown]
# # **Clasificación de Razas de Perros con Deep Learning**
#
# ## Objetivo del proyecto
#
# Este proyecto explora distintas estrategias de clasificación de imágenes utilizando redes neuronales convolucionales (CNNs) y técnicas de *transfer learning* sobre un dataset de razas de perros.
#
# El objetivo principal es comparar diferentes enfoques de modelado y evaluar cómo afectan al rendimiento final del sistema de clasificación.
#
# A lo largo del proyecto se desarrollan y comparan los siguientes enfoques:
#
# - Modelo base completamente conectado
# - CNN diseñada desde cero
# - Optimización mediante regularización y ajuste de hiperparámetros
# - Transfer Learning con InceptionV3
# - Técnicas de Data Augmentation
# - AutoML con AutoKeras
#
# ## Tecnologías utilizadas
#
# - Python
# - TensorFlow / Keras
# - AutoKeras
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
#
# ## Dataset
#
# El dataset utilizado en este proyecto se encuentra publicado en Hugging Face.
#
# El conjunto de datos contiene más de 12.000 imágenes distribuidas en 74 razas distintas de perros y se utiliza para entrenar modelos de clasificación multiclase mediante Deep Learning.
#
# ## Fuente del dataset
#
# https://huggingface.co/datasets/lpastor75/dog-breed-classification
#
# ## Descarga del dataset
#
# El dataset se encuentra publicado en Hugging Face y se descarga automáticamente utilizando `huggingface_hub`.

# %% [markdown]
# ## Instalación de dependencias
#
# Este notebook instala automáticamente las librerías necesarias para garantizar reproducibilidad en cualquier entorno (Colab, local o Kaggle).

# %%
# Instalación de dependencias
# !pip install -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 14.3 MB/s eta 0:00:00

# %%
import os
import glob
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

import tensorflow as tf
import autokeras as ak

from sklearn.model_selection import train_test_split
from sklearn import metrics

plt.style.use("ggplot")

# ============================================
# REPRODUCIBILIDAD
# ============================================

SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ============================================
# CONFIGURACIÓN GLOBAL
# ============================================

IMG_SIZE_BASE = (100, 120, 3)
IMG_SIZE_TRANSFER = (299, 299, 3)

BATCH_SIZE = 128
EPOCHS = 10

# %%
# Instalación de dependencias necesarias

# !pip install -q huggingface_hub

# %%
# Descarga del dataset desde Hugging Face

from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="lpastor75/dog-breed-classification",
    repo_type="dataset",
    local_dir="dog-breed-dataset"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# '/content/dog-breed-dataset'

# %% [markdown]
# # Estructura del dataset
#
# Tras la descarga, la estructura local del dataset será:
# ```
# dog-breed-dataset/
# │
# ├── README.md
# ├── train.csv
# ├── valid.csv
# ├── test.csv
# └── dog-images.zip
# ```
# Las imágenes se encuentran comprimidas en un único archivo ZIP para optimizar almacenamiento y transferencia.

# %%
# Descompresión del dataset

import zipfile

zip_path = "dog-breed-dataset/dog-images.zip"

extract_path = "dog-breed-dataset/"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset descomprimido correctamente.")
# Out:
# Dataset descomprimido correctamente.

# %% [markdown]
# ## Carga de imágenes y etiquetas
#
# Se generan automáticamente:
# - las rutas de las imágenes
# - las clases disponibles
# - las etiquetas numéricas necesarias para entrenamiento

# %%
# Directorio raíz de imágenes
dataset_path = "dog-breed-dataset/dog-images"

# Clases disponibles
classes = sorted([
    folder_name
    for folder_name in os.listdir(dataset_path)
    if os.path.isdir(os.path.join(dataset_path, folder_name))
])

# Diccionarios de conversión
num_to_label = {
    i: c
    for i, c in enumerate(classes)
}

label_to_num = {
    c: i
    for i, c in enumerate(classes)
}

# Rutas completas de imágenes
image_paths = np.array(
    glob.glob(
        os.path.join(dataset_path, "**", "*.jpg"),
        recursive=True
    )
)

# Etiquetas numéricas
image_labels = np.array([
    label_to_num[
        os.path.basename(os.path.dirname(path))
    ]
    for path in image_paths
])

print(f"Número total de imágenes: {len(image_paths)}")
print(f"Número total de clases: {len(classes)}")
# Out:
# Número total de imágenes: 12891
# Número total de clases: 74

# %% [markdown]
# ## Reproducibilidad
#
# El dataset se descarga directamente desde Hugging Face para garantizar:
# - reproducibilidad
# - versionado
# - trazabilidad de datos
# - portabilidad del proyecto

# %% [markdown]
# ## Exploración visual del dataset
#
# Antes de entrenar los modelos, se realiza una inspección visual rápida del dataset para verificar:
#
# - diversidad de imágenes
# - variabilidad de tamaños
# - diferencias entre clases
# - calidad general de los datos
#
# Este paso es importante para detectar posibles problemas de calidad o sesgos antes del entrenamiento.

# %%
def show_images(img_paths, n_images=25):

    fig = plt.figure(figsize=(15, 15))

    random_indices = np.random.randint(
        len(img_paths),
        size=n_images
    )

    for i in range(n_images):

        fig.add_subplot(5, 5, i + 1)

        plt.axis("off")

        img = Image.open(img_paths[random_indices[i]])

        plt.imshow(img)

    plt.tight_layout()
    plt.show()


show_images(image_paths)

# %% [markdown]
# # **Distribución de clases**
#
# Se analiza el número de imágenes disponibles por raza para comprobar si el dataset presenta desbalanceo entre clases.

# %%
os.makedirs("images", exist_ok=True)

targets = [
    len(
        glob.glob(
            os.path.join(dataset_path, c, "*.jpg")
        )
    )
    for c in classes
]

plt.figure(figsize=(20, 6))

plt.bar(classes, targets)

plt.xticks(rotation=90)

plt.title("Distribución de imágenes por clase")

plt.xlabel("Clase")

plt.ylabel("Número de imágenes")

plt.savefig("images/class_distribution.png", bbox_inches="tight")

plt.show()

# %% [markdown]
# ## División del dataset
#
# El dataset se divide en tres subconjuntos:
#
# - entrenamiento
# - validación
# - test
#
# La partición se realiza manteniendo la distribución original de clases mediante muestreo estratificado.

# %%
# Mezcla aleatoria
shuffler = np.random.permutation(len(image_paths))

image_paths = image_paths[shuffler]
image_labels = image_labels[shuffler]

# División train/test
x_train_valid, x_test, y_train_valid, y_test = train_test_split(
    image_paths,
    image_labels,
    test_size=0.10,
    random_state=SEED,
    stratify=image_labels
)

# División train/validation
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_valid,
    y_train_valid,
    test_size=0.20,
    random_state=SEED,
    stratify=y_train_valid
)

print(f"Train samples: {x_train.shape[0]}")
print(f"Validation samples: {x_valid.shape[0]}")
print(f"Test samples: {x_test.shape[0]}")
# Out:
# Train samples: 9280
# Validation samples: 2321
# Test samples: 1290

# %% [markdown]
# ## Pipeline de carga de datos
#
# Se implementa un pipeline basado en `tf.data.Dataset` para optimizar:
#
# - lectura de imágenes
# - preprocesamiento
# - batching
# - rendimiento durante entrenamiento
#
# Este enfoque es más eficiente y escalable para proyectos de Deep Learning.

# %%
def read_image(image_path, label):

    contents = tf.io.read_file(image_path)

    img = tf.image.decode_jpeg(
        contents,
        channels=3
    )

    img = tf.cast(img, tf.float32)

    img /= 255.0

    return img, label


def resize_image(img, label, target_size):

    resized_img = tf.image.resize(
        img,
        target_size
    )

    return resized_img, label


def get_dataset(
    image_paths,
    image_labels,
    target_size,
    batch_size,
    prep_func=None
):

    dataset = tf.data.Dataset.from_tensor_slices(
        (image_paths, image_labels)
    )

    dataset = dataset.map(
        read_image,
        num_parallel_calls=tf.data.AUTOTUNE
    )

    dataset = dataset.map(
        lambda x, y: resize_image(x, y, target_size),
        num_parallel_calls=tf.data.AUTOTUNE
    )

    if prep_func is not None:

        dataset = dataset.map(
            lambda x, y: (x * 255.0, y),
            num_parallel_calls=tf.data.AUTOTUNE
        )

        dataset = dataset.map(
            lambda x, y: (prep_func(x), y),
            num_parallel_calls=tf.data.AUTOTUNE
        )

    dataset = dataset.batch(batch_size)

    dataset = dataset.prefetch(tf.data.AUTOTUNE)

    return dataset

# %% [markdown]
# # **Modelo baseline**
#
# Se construye un modelo inicial sencillo para establecer una referencia base de rendimiento.
#
# Este modelo permitirá comparar posteriormente arquitecturas convolucionales más avanzadas y técnicas de transferencia de aprendizaje.

# %%
train_dataset = get_dataset(
    x_train,
    y_train,
    IMG_SIZE_BASE[:-1],
    BATCH_SIZE
)

valid_dataset = get_dataset(
    x_valid,
    y_valid,
    IMG_SIZE_BASE[:-1],
    BATCH_SIZE
)

test_dataset = get_dataset(
    x_test,
    y_test,
    IMG_SIZE_BASE[:-1],
    BATCH_SIZE
)

# %%
model = tf.keras.Sequential([

    tf.keras.layers.Input(shape=IMG_SIZE_BASE),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(
        1,
        activation="relu"
    ),

    tf.keras.layers.Dense(
        len(classes),
        activation="softmax"
    )
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 36000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        36,001 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 74)             │           148 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36,149 (141.21 KB)
#  Trainable params: 36,149 (141.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001
)

model.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_dataset,
    epochs=2,
    validation_data=valid_dataset
)
# Out:
# Epoch 1/2
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 34s 429ms/step - accuracy: 0.0179 - loss: 4.3036 - val_accuracy: 0.0198 - val_loss: 4.3023
# Epoch 2/2
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 24s 216ms/step - accuracy: 0.0195 - loss: 4.3020 - val_accuracy: 0.0198 - val_loss: 4.3009

# %%
test_loss, test_accuracy = model.evaluate(
    test_dataset
)

print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.0194 - loss: 4.3008
# Test accuracy: 0.0194

# %% [markdown]
# ## Evolución del entrenamiento
#
# Se analiza la evolución de:
#
# - función de pérdida
# - accuracy en entrenamiento
# - accuracy en validación
#
# para detectar posibles problemas de:
# - underfitting
# - overfitting
# - convergencia

# %%
plt.figure(figsize=(14, 5))

# Loss
plt.subplot(1, 2, 1)

plt.plot(history.history["loss"], label="Train Loss")

plt.plot(history.history["val_loss"], label="Validation Loss")

plt.title("Loss")

plt.legend()

# Accuracy
plt.subplot(1, 2, 2)

plt.plot(history.history["accuracy"], label="Train Accuracy")

plt.plot(history.history["val_accuracy"], label="Validation Accuracy")

plt.title("Accuracy")

plt.legend()

plt.show()

# %% [markdown]
# ## Matriz de confusión
#
# La matriz de confusión permite identificar:
#
# - clases con mayor tasa de error
# - confusiones frecuentes entre razas
# - comportamiento global del modelo

# %%
predictions = model.predict(test_dataset)

y_pred = np.argmax(predictions, axis=1)

conf_matrix = metrics.confusion_matrix(
    y_true=y_test,
    y_pred=y_pred
)

df_cm = pd.DataFrame(
    conf_matrix,
    index=classes,
    columns=classes
)

plt.figure(figsize=(20, 20))

sns.heatmap(
    df_cm,
    cmap="Blues"
)

plt.title("Confusion Matrix")

plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 224ms/step

# %% [markdown]
# ---
#
# # **Entrenamiento de una CNN desde cero**
#
# En esta sección se desarrolla una Red Neuronal Convolucional (CNN) para clasificación multiclase de razas de perro.
#
# El objetivo es construir un modelo base entrenado completamente desde cero y analizar su comportamiento antes de aplicar técnicas más avanzadas como regularización, transfer learning o data augmentation.
#
# ### Arquitectura del modelo
#
# La red sigue una arquitectura inspirada en modelos tipo VGG:
#
# - Tamaño de entrada: `(100, 120, 3)`
# - Capa convolucional con 32 filtros y activación ReLU
# - Capa MaxPooling
# - Capa convolucional con 64 filtros y activación ReLU
# - Capa MaxPooling
# - Capa fully connected con 1024 neuronas
# - Capa de salida Softmax
#
# ### Configuración del entrenamiento
#
# | Parámetro | Valor |
# |---|---|
# | Optimizador | Adam |
# | Learning Rate | 0.001 |
# | Función de pérdida | Sparse Categorical Crossentropy |
# | Batch Size | 128 |
# | Epochs | 10 |
#
# ---

# %%
# Configuración de datasets

train_dataset = get_dataset(
    x_train,
    y_train,
    IMG_SIZE_BASE[:-1],
    BATCH_SIZE
)

valid_dataset = get_dataset(
    x_valid,
    y_valid,
    IMG_SIZE_BASE[:-1],
    BATCH_SIZE
)

test_dataset = get_dataset(
    x_test,
    y_test,
    IMG_SIZE_BASE[:-1],
    BATCH_SIZE
)

# %%
# Definición del modelo CNN

cnn_model = tf.keras.Sequential([

    tf.keras.Input(shape=IMG_SIZE_BASE),

    tf.keras.layers.Conv2D(
        32,
        (5, 5),
        padding="same",
        activation="relu"
    ),

    tf.keras.layers.MaxPool2D(
        pool_size=(2, 2)
    ),

    tf.keras.layers.Conv2D(
        64,
        (5, 5),
        padding="same",
        activation="relu"
    ),

    tf.keras.layers.MaxPool2D(
        pool_size=(2, 2)
    ),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(
        1024,
        activation="relu"
    ),

    tf.keras.layers.Dense(
        len(classes),
        activation="softmax"
    )
])

cnn_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 100, 120, 32)   │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 50, 60, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 50, 60, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 25, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 48000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1024)           │    49,153,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 74)             │        75,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,282,570 (188.00 MB)
#  Trainable params: 49,282,570 (188.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilación del modelo

cnn_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Entrenamiento

history_cnn = cnn_model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS
)
# Out:
# Epoch 1/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 29s 279ms/step - accuracy: 0.0206 - loss: 4.4989 - val_accuracy: 0.0302 - val_loss: 4.2499
# Epoch 2/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.0561 - loss: 4.0704 - val_accuracy: 0.0560 - val_loss: 4.1160
# Epoch 3/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.1559 - loss: 3.5143 - val_accuracy: 0.0577 - val_loss: 4.5779
# Epoch 4/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 15s 199ms/step - accuracy: 0.3135 - loss: 2.8140 - val_accuracy: 0.0452 - val_loss: 5.8588
# Epoch 5/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 22s 224ms/step - accuracy: 0.4878 - loss: 2.0267 - val_accuracy: 0.0483 - val_loss: 6.3972
# Epoch 6/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.6863 - loss: 1.2367 - val_accuracy: 0.0495 - val_loss: 7.9665
# Epoch 7/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.8162 - loss: 0.7284 - val_accuracy: 0.0573 - val_loss: 8.4696
# Epoch 8/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9113 - loss: 0.3658 - val_accuracy: 0.0573 - val_loss: 9.7497
# Epoch 9/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9537 - loss: 0.2132 - val_accuracy: 0.0607 - val_loss: 10.0532
# Epoch 10/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9635 - loss: 0.1653 - val_accuracy: 0.0569 - val_loss: 10.4136

# %%
# Evaluación final sobre test

test_loss, test_accuracy = cnn_model.evaluate(test_dataset)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 276ms/step - accuracy: 0.0643 - loss: 10.1616
# Test Loss: 10.1616
# Test Accuracy: 0.0643

# %% [markdown]
# ## Análisis del entrenamiento
#
# Las siguientes gráficas muestran la evolución de las métricas de entrenamiento y validación durante el proceso de optimización.
#
# Se monitorizan dos indicadores principales:
#
# - Accuracy
# - Loss
#
# Estas curvas permiten analizar el comportamiento del modelo y detectar posibles problemas de sobreajuste.
#
# ---

# %%
# Visualización del entrenamiento

plt.figure(figsize=(14, 5))

# Accuracy
plt.subplot(1, 2, 1)

plt.plot(
    history_cnn.history["accuracy"],
    label="Training Accuracy"
)

plt.plot(
    history_cnn.history["val_accuracy"],
    label="Validation Accuracy"
)

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()

# Loss
plt.subplot(1, 2, 2)

plt.plot(
    history_cnn.history["loss"],
    label="Training Loss"
)

plt.plot(
    history_cnn.history["val_loss"],
    label="Validation Loss"
)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Matriz de confusión
#
# La matriz de confusión permite analizar en detalle el rendimiento del modelo para cada una de las clases del problema.
#
# Este análisis facilita identificar:
#
# - Razas correctamente clasificadas
# - Clases con mayor nivel de confusión
# - Posibles problemas de desbalanceo
#
# ---

# %%
# Predicciones sobre el conjunto de test

predictions = cnn_model.predict(test_dataset)

y_pred = np.argmax(predictions, axis=1)
y_true = y_test

# Matriz de confusión

conf_matrix = metrics.confusion_matrix(
    y_true=y_true,
    y_pred=y_pred
)

# Visualización

df_cm = pd.DataFrame(
    conf_matrix,
    index=classes,
    columns=classes
)

plt.figure(figsize=(20, 20))

sns.heatmap(
    df_cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step

# %% [markdown]
# ## Resultados y conclusiones
#
# La CNN base consigue aprender patrones visuales relevantes y obtiene un rendimiento razonable sobre el dataset.
#
# Sin embargo, las curvas de entrenamiento y validación muestran síntomas claros de sobreajuste:
#
# - El accuracy de entrenamiento continúa aumentando
# - El accuracy de validación se estabiliza rápidamente
# - La loss de validación deja de mejorar tras varias epochs
#
# Este comportamiento sugiere que la complejidad del modelo es elevada en relación con el tamaño del dataset disponible.
#
# En las siguientes secciones se introducirán técnicas adicionales para mejorar la capacidad de generalización del modelo:
#
# - Regularización mediante Dropout
# - Data Augmentation
# - Transfer Learning con modelos preentrenados
#
# ---

# %% [markdown]
# ---
#
# ## **Optimización de hiperparámetros y regularización**
#
# En este experimento se incorporan técnicas de regularización para reducir el sobreajuste detectado en la CNN inicial.
#
# La nueva arquitectura introduce capas Dropout y una mayor profundidad en la extracción de características.
#
# ### Mejoras introducidas
#
# - Bloques convolucionales adicionales
# - Regularización mediante Dropout
# - Mayor capacidad de extracción de features
#
# ### Arquitectura actualizada
#
# - Tamaño de entrada: `(100, 120, 3)`
# - Conv2D → MaxPooling
# - Dropout (0.5)
# - Conv2D → MaxPooling
# - Conv2D → MaxPooling
# - Dropout (0.5)
# - Dense de 1024 neuronas
# - Dropout (0.2)
# - Capa Softmax de salida
#
# ---

# %%
# Modelo CNN regularizado con Dropout

regularized_model = tf.keras.Sequential([

    tf.keras.Input(shape=IMG_SIZE_BASE),

    tf.keras.layers.Conv2D(
        32,
        (5, 5),
        padding="same",
        activation="relu"
    ),

    tf.keras.layers.MaxPool2D(
        pool_size=(2, 2),
        padding="same"
    ),

    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Conv2D(
        64,
        (5, 5),
        padding="same",
        activation="relu"
    ),

    tf.keras.layers.MaxPool2D(
        pool_size=(2, 2),
        padding="same"
    ),

    tf.keras.layers.Conv2D(
        64,
        (5, 5),
        padding="same",
        activation="relu"
    ),

    tf.keras.layers.MaxPool2D(
        pool_size=(2, 2),
        padding="same"
    ),

    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(
        1024,
        activation="relu"
    ),

    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Dense(
        len(classes),
        activation="softmax"
    )
])

regularized_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 100, 120, 32)   │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 50, 60, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 60, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 50, 60, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 25, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 25, 30, 64)     │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 13, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 13, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 12480)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1024)           │    12,780,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 74)             │        75,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,012,554 (49.64 MB)
#  Trainable params: 13,012,554 (49.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilación

regularized_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Entrenamiento

history_regularized = regularized_model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS
)
# Out:
# Epoch 1/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 28s 284ms/step - accuracy: 0.0182 - loss: 4.3025 - val_accuracy: 0.0241 - val_loss: 4.2526
# Epoch 2/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.0462 - loss: 4.0788 - val_accuracy: 0.0582 - val_loss: 4.0052
# Epoch 3/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 26s 352ms/step - accuracy: 0.0806 - loss: 3.8545 - val_accuracy: 0.0879 - val_loss: 3.8988
# Epoch 4/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.1030 - loss: 3.7380 - val_accuracy: 0.0832 - val_loss: 3.8539
# Epoch 5/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.1291 - loss: 3.6004 - val_accuracy: 0.0931 - val_loss: 3.8348
# Epoch 6/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 21s 202ms/step - accuracy: 0.1533 - loss: 3.4291 - val_accuracy: 0.0879 - val_loss: 3.8953
# Epoch 7/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 20s 191ms/step - accuracy: 0.1834 - loss: 3.2914 - val_accuracy: 0.0922 - val_loss: 3.9576
# Epoch 8/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.2152 - loss: 3.1390 - val_accuracy: 0.0866 - val_loss: 4.0733
# Epoch 9/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.2501 - loss: 2.9538 - val_accuracy: 0.0982 - val_loss: 3.9596
# Epoch 10/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.2859 - loss: 2.7980 - val_accuracy: 0.1051 - val_loss: 3.9051

# %%
test_dataset = get_dataset(
    x_test,
    y_test,
    IMG_SIZE_BASE[:-1],
    BATCH_SIZE
)

# %%
# Evaluación final sobre test

test_loss, test_accuracy = regularized_model.evaluate(test_dataset)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.0814 - loss: 3.9205
# Test Loss: 3.9205
# Test Accuracy: 0.0814

# %%
# Visualización del entrenamiento

plt.figure(figsize=(14, 5))

# Accuracy
plt.subplot(1, 2, 1)

plt.plot(
    history_regularized.history["accuracy"],
    label="Training Accuracy"
)

plt.plot(
    history_regularized.history["val_accuracy"],
    label="Validation Accuracy"
)

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()

# Loss
plt.subplot(1, 2, 2)

plt.plot(
    history_regularized.history["loss"],
    label="Training Loss"
)

plt.plot(
    history_regularized.history["val_loss"],
    label="Validation Loss"
)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Predicciones sobre el conjunto de test

predictions = regularized_model.predict(test_dataset)

y_pred = np.argmax(predictions, axis=1)
y_true = y_test

# Matriz de confusión

conf_matrix = metrics.confusion_matrix(
    y_true=y_true,
    y_pred=y_pred
)

# Visualización

df_cm = pd.DataFrame(
    conf_matrix,
    index=classes,
    columns=classes
)

plt.figure(figsize=(20, 20))

sns.heatmap(
    df_cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step

# %% [markdown]
# ## Resultados y conclusiones
#
# La incorporación de capas Dropout mejora ligeramente la estabilidad del entrenamiento y reduce parcialmente el sobreajuste respecto al modelo inicial.
#
# Aun así, el rendimiento en validación continúa estabilizándose de forma temprana, lo que indica que el tamaño del dataset sigue siendo una limitación importante.
#
# Este experimento demuestra la importancia de equilibrar:
#
# - Complejidad del modelo
# - Tamaño del dataset
# - Nivel de regularización
#
# En la siguiente sección se utilizará Transfer Learning con InceptionV3 para aprovechar características previamente aprendidas sobre ImageNet.
#
# ---

# %% [markdown]
# # **Transfer Learning con InceptionV3**
#
# ## Objetivo
#
# En esta fase del proyecto se implementa una estrategia de **Transfer Learning** utilizando el modelo preentrenado **InceptionV3**.
# El objetivo es aprovechar el conocimiento previamente adquirido sobre el dataset **ImageNet** para mejorar el rendimiento del clasificador de razas de perros.
#
# A diferencia de las arquitecturas entrenadas desde cero, los modelos preentrenados permiten:
#
# - Reducir significativamente el tiempo de entrenamiento
# - Obtener mejores métricas con datasets medianos
# - Minimizar problemas de sobreajuste
# - Aprovechar características visuales ya aprendidas
#
# Para este experimento:
#
# - Se congela la base convolucional de InceptionV3
# - Se añade una capa `Dropout` para regularización
# - Se incorpora una nueva capa de clasificación adaptada al número de razas del dataset
#
# ---
#
# ## Configuración del modelo
#
# | Parámetro | Valor |
# |---|---|
# | Arquitectura base | InceptionV3 |
# | Input shape | `(299, 299, 3)` |
# | Pesos preentrenados | `ImageNet` |
# | Pooling | `avg` |
# | Dropout | `0.5` |
# | Optimizador | Adam |
# | Learning Rate | `0.001` |
# | Epochs | `10` |
# | Batch Size | `128` |

# %%
# Configuración de datasets para InceptionV3

train_dataset = get_dataset(
    x_train,
    y_train,
    IMG_SIZE_TRANSFER[:-1],
    BATCH_SIZE,
    tf.keras.applications.inception_v3.preprocess_input
)

valid_dataset = get_dataset(
    x_valid,
    y_valid,
    IMG_SIZE_TRANSFER[:-1],
    BATCH_SIZE,
    tf.keras.applications.inception_v3.preprocess_input
)

test_dataset = get_dataset(
    x_test,
    y_test,
    IMG_SIZE_TRANSFER[:-1],
    BATCH_SIZE,
    tf.keras.applications.inception_v3.preprocess_input
)

# %%
# Carga del modelo preentrenado

base_model = tf.keras.applications.InceptionV3(
    include_top=False,
    weights="imagenet",
    pooling="avg"
)

# Congelación de pesos
for layer in base_model.layers:
    layer.trainable = False

# Construcción del clasificador final

x = tf.keras.layers.Dropout(0.5)(base_model.output)

outputs = tf.keras.layers.Dense(
    len(classes),
    activation="softmax"
)(x)

model = tf.keras.Model(
    inputs=base_model.input,
    outputs=outputs
)

# Compilación

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, None,      │        864 │ input_layer_3[0]… │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, None,      │         96 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, None,      │      9,216 │ activation[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │         96 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, None,      │     18,432 │ activation_1[0][… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, None,      │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, None,      │      5,120 │ max_pooling2d_5[… │
# │                     │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        240 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, None,      │    138,240 │ activation_3[0][… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, None,      │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │     12,288 │ max_pooling2d_6[… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │      9,216 │ max_pooling2d_6[… │
# │                     │ None, 48)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │     55,296 │ activation_8[0][… │
# │                     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        144 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ None, 48)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        288 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 48)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, None,      │          0 │ max_pooling2d_6[… │
# │ (AveragePooling2D)  │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, None,      │     12,288 │ max_pooling2d_6[… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │     76,800 │ activation_6[0][… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, None,      │     82,944 │ activation_9[0][… │
# │                     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, None,      │      6,144 │ average_pooling2… │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        288 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │         96 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed0              │ (None, None,      │          0 │ activation_5[0][… │
# │ (Concatenate)       │ None, 256)        │            │ activation_7[0][… │
# │                     │                   │            │ activation_10[0]… │
# │                     │                   │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, None,      │     16,384 │ mixed0[0][0]      │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, None,      │     12,288 │ mixed0[0][0]      │
# │                     │ None, 48)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, None,      │     55,296 │ activation_15[0]… │
# │                     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        144 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ None, 48)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        288 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 48)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, None,      │          0 │ mixed0[0][0]      │
# │ (AveragePooling2D)  │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, None,      │     16,384 │ mixed0[0][0]      │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, None,      │     76,800 │ activation_13[0]… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, None,      │     82,944 │ activation_16[0]… │
# │                     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, None,      │     16,384 │ average_pooling2… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        288 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed1              │ (None, None,      │          0 │ activation_12[0]… │
# │ (Concatenate)       │ None, 288)        │            │ activation_14[0]… │
# │                     │                   │            │ activation_17[0]… │
# │                     │                   │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, None,      │     18,432 │ mixed1[0][0]      │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, None,      │     13,824 │ mixed1[0][0]      │
# │                     │ None, 48)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, None,      │     55,296 │ activation_22[0]… │
# │                     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        144 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ None, 48)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        288 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 48)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, None,      │          0 │ mixed1[0][0]      │
# │ (AveragePooling2D)  │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, None,      │     18,432 │ mixed1[0][0]      │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, None,      │     76,800 │ activation_20[0]… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, None,      │     82,944 │ activation_23[0]… │
# │                     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, None,      │     18,432 │ average_pooling2… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        288 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed2              │ (None, None,      │          0 │ activation_19[0]… │
# │ (Concatenate)       │ None, 288)        │            │ activation_21[0]… │
# │                     │                   │            │ activation_24[0]… │
# │                     │                   │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, None,      │     18,432 │ mixed2[0][0]      │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        192 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, None,      │     55,296 │ activation_27[0]… │
# │                     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        288 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, None,      │    995,328 │ mixed2[0][0]      │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, None,      │     82,944 │ activation_28[0]… │
# │                     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        288 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, None,      │          0 │ mixed2[0][0]      │
# │ (MaxPooling2D)      │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed3              │ (None, None,      │          0 │ activation_26[0]… │
# │ (Concatenate)       │ None, 768)        │            │ activation_29[0]… │
# │                     │                   │            │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, None,      │     98,304 │ mixed3[0][0]      │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        384 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, None,      │    114,688 │ activation_34[0]… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        384 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, None,      │     98,304 │ mixed3[0][0]      │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, None,      │    114,688 │ activation_35[0]… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        384 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        384 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, None,      │    114,688 │ activation_31[0]… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, None,      │    114,688 │ activation_36[0]… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        384 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        384 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_3 │ (None, None,      │          0 │ mixed3[0][0]      │
# │ (AveragePooling2D)  │ None, 768)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, None,      │    147,456 │ mixed3[0][0]      │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, None,      │    172,032 │ activation_32[0]… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, None,      │    172,032 │ activation_37[0]… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, None,      │    147,456 │ average_pooling2… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed4              │ (None, None,      │          0 │ activation_30[0]… │
# │ (Concatenate)       │ None, 768)        │            │ activation_33[0]… │
# │                     │                   │            │ activation_38[0]… │
# │                     │                   │            │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, None,      │    122,880 │ mixed4[0][0]      │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, None,      │    179,200 │ activation_44[0]… │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, None,      │    122,880 │ mixed4[0][0]      │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, None,      │    179,200 │ activation_45[0]… │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_46[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_51[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, None,      │    179,200 │ activation_41[0]… │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, None,      │    179,200 │ activation_46[0]… │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_47[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_4 │ (None, None,      │          0 │ mixed4[0][0]      │
# │ (AveragePooling2D)  │ None, 768)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, None,      │    147,456 │ mixed4[0][0]      │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, None,      │    215,040 │ activation_42[0]… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, None,      │    215,040 │ activation_47[0]… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, None,      │    147,456 │ average_pooling2… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_48[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed5              │ (None, None,      │          0 │ activation_40[0]… │
# │ (Concatenate)       │ None, 768)        │            │ activation_43[0]… │
# │                     │                   │            │ activation_48[0]… │
# │                     │                   │            │ activation_49[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, None,      │    122,880 │ mixed5[0][0]      │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_59[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, None,      │    179,200 │ activation_54[0]… │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_60[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, None,      │    122,880 │ mixed5[0][0]      │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, None,      │    179,200 │ activation_55[0]… │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_56[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_61[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, None,      │    179,200 │ activation_51[0]… │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, None,      │    179,200 │ activation_56[0]… │
# │                     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_57[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        480 │ conv2d_62[0][0]   │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_5 │ (None, None,      │          0 │ mixed5[0][0]      │
# │ (AveragePooling2D)  │ None, 768)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, None,      │    147,456 │ mixed5[0][0]      │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, None,      │    215,040 │ activation_52[0]… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_63 (Conv2D)  │ (None, None,      │    215,040 │ activation_57[0]… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_64 (Conv2D)  │ (None, None,      │    147,456 │ average_pooling2… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_58[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_63[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_64[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed6              │ (None, None,      │          0 │ activation_50[0]… │
# │ (Concatenate)       │ None, 768)        │            │ activation_53[0]… │
# │                     │                   │            │ activation_58[0]… │
# │                     │                   │            │ activation_59[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_69 (Conv2D)  │ (None, None,      │    147,456 │ mixed6[0][0]      │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_69[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_64       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_70 (Conv2D)  │ (None, None,      │    258,048 │ activation_64[0]… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_70[0][0]   │
# ...
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, None,      │          0 │ mixed7[0][0]      │
# │ (MaxPooling2D)      │ None, 768)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed8              │ (None, None,      │          0 │ activation_71[0]… │
# │ (Concatenate)       │ None, 1280)       │            │ activation_75[0]… │
# │                     │                   │            │ max_pooling2d_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, None,      │    573,440 │ mixed8[0][0]      │
# │                     │ None, 448)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,344 │ conv2d_85[0][0]   │
# │ (BatchNormalizatio… │ None, 448)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_80       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 448)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_82 (Conv2D)  │ (None, None,      │    491,520 │ mixed8[0][0]      │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_86 (Conv2D)  │ (None, None,      │  1,548,288 │ activation_80[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_82[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_86[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_77       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_81       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_83 (Conv2D)  │ (None, None,      │    442,368 │ activation_77[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, None,      │    442,368 │ activation_77[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, None,      │    442,368 │ activation_81[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, None,      │    442,368 │ activation_81[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_7 │ (None, None,      │          0 │ mixed8[0][0]      │
# │ (AveragePooling2D)  │ None, 1280)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, None,      │    409,600 │ mixed8[0][0]      │
# │                     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_83[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_84[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_87[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_88[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, None,      │    245,760 │ average_pooling2… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        960 │ conv2d_81[0][0]   │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_78       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_79       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_82       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_83       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_89[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_76       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed9_0            │ (None, None,      │          0 │ activation_78[0]… │
# │ (Concatenate)       │ None, 768)        │            │ activation_79[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, None,      │          0 │ activation_82[0]… │
# │ (Concatenate)       │ None, 768)        │            │ activation_83[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_84       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed9              │ (None, None,      │          0 │ activation_76[0]… │
# │ (Concatenate)       │ None, 2048)       │            │ mixed9_0[0][0],   │
# │                     │                   │            │ concatenate[0][0… │
# │                     │                   │            │ activation_84[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, None,      │    917,504 │ mixed9[0][0]      │
# │                     │ None, 448)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,344 │ conv2d_94[0][0]   │
# │ (BatchNormalizatio… │ None, 448)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_89       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 448)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, None,      │    786,432 │ mixed9[0][0]      │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, None,      │  1,548,288 │ activation_89[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_91[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_95[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_86       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_90       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, None,      │    442,368 │ activation_86[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, None,      │    442,368 │ activation_86[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, None,      │    442,368 │ activation_90[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, None,      │    442,368 │ activation_90[0]… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_8 │ (None, None,      │          0 │ mixed9[0][0]      │
# │ (AveragePooling2D)  │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, None,      │    655,360 │ mixed9[0][0]      │
# │                     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_92[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_93[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_96[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,152 │ conv2d_97[0][0]   │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, None,      │    393,216 │ average_pooling2… │
# │                     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        960 │ conv2d_90[0][0]   │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_87       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_88       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_91       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_92       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │        576 │ conv2d_98[0][0]   │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_85       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed9_1            │ (None, None,      │          0 │ activation_87[0]… │
# │ (Concatenate)       │ None, 768)        │            │ activation_88[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, None,      │          0 │ activation_91[0]… │
# │ (Concatenate)       │ None, 768)        │            │ activation_92[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_93       │ (None, None,      │          0 │ batch_normalizat… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed10             │ (None, None,      │          0 │ activation_85[0]… │
# │ (Concatenate)       │ None, 2048)       │            │ mixed9_1[0][0],   │
# │                     │                   │            │ concatenate_1[0]… │
# │                     │                   │            │ activation_93[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ mixed10[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 74)        │    151,626 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,954,410 (83.75 MB)
#  Trainable params: 151,626 (592.29 KB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
# Entrenamiento del modelo

history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS
)
# Out:
# Epoch 1/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 106s 959ms/step - accuracy: 0.7308 - loss: 1.5722 - val_accuracy: 0.9496 - val_loss: 0.3084
# Epoch 2/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 36s 494ms/step - accuracy: 0.9452 - loss: 0.2702 - val_accuracy: 0.9561 - val_loss: 0.1946
# Epoch 3/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 502ms/step - accuracy: 0.9536 - loss: 0.1889 - val_accuracy: 0.9582 - val_loss: 0.1641
# Epoch 4/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 38s 512ms/step - accuracy: 0.9595 - loss: 0.1560 - val_accuracy: 0.9591 - val_loss: 0.1538
# Epoch 5/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 38s 516ms/step - accuracy: 0.9647 - loss: 0.1326 - val_accuracy: 0.9578 - val_loss: 0.1441
# Epoch 6/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 38s 523ms/step - accuracy: 0.9712 - loss: 0.1121 - val_accuracy: 0.9591 - val_loss: 0.1409
# Epoch 7/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 38s 516ms/step - accuracy: 0.9705 - loss: 0.1058 - val_accuracy: 0.9578 - val_loss: 0.1418
# Epoch 8/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 38s 520ms/step - accuracy: 0.9752 - loss: 0.0910 - val_accuracy: 0.9565 - val_loss: 0.1390
# Epoch 9/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 42s 578ms/step - accuracy: 0.9775 - loss: 0.0845 - val_accuracy: 0.9595 - val_loss: 0.1379
# Epoch 10/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 38s 522ms/step - accuracy: 0.9784 - loss: 0.0777 - val_accuracy: 0.9578 - val_loss: 0.1371

# %%
# Evaluación sobre test set

test_loss, test_accuracy = model.evaluate(test_dataset)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9519 - loss: 0.1562
# Test Loss: 0.1562
# Test Accuracy: 0.9519

# %% [markdown]
# ## Análisis del entrenamiento
#
# A continuación se visualiza la evolución de las métricas principales durante el proceso de entrenamiento:
#
# - Accuracy
# - Validation Accuracy
# - Loss
# - Validation Loss
#
# Estas gráficas permiten detectar posibles problemas de:
# - Sobreajuste
# - Infraentrenamiento
# - Estabilidad del modelo

# %%
# Evolución del entrenamiento

plt.figure(figsize=(14, 5))

# Accuracy
plt.subplot(1, 2, 1)

plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")

plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.legend()

# Loss
plt.subplot(1, 2, 2)

plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend()

plt.tight_layout()
plt.savefig("images/training_curves_inceptionv3.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Matriz de confusión
#
# La matriz de confusión permite analizar el comportamiento del modelo clase por clase, identificando:
#
# - Razas correctamente clasificadas
# - Clases con mayor confusión
# - Posibles sesgos del dataset
# - Categorías visualmente similares

# %%
# Predicciones

predictions = model.predict(test_dataset)

y_pred = np.argmax(predictions, axis=1)
y_true = y_test

# Confusion Matrix

conf_matrix = metrics.confusion_matrix(
    y_true=y_true,
    y_pred=y_pred
)

df_cm = pd.DataFrame(
    conf_matrix,
    index=classes,
    columns=classes
)

# Visualización

plt.figure(figsize=(20, 20))

sns.heatmap(
    df_cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.savefig("images/confusion_matrix_inceptionv3.png", bbox_inches="tight")
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step

# %% [markdown]
# ## Resultados
#
# El enfoque basado en **Transfer Learning** obtiene el mejor rendimiento de todos los experimentos realizados en el proyecto.
#
# ### Observaciones principales
#
# - La convergencia es rápida y estable
# - El modelo generaliza correctamente sobre validación y test
# - El sobreajuste se reduce considerablemente
# - Se alcanza una precisión significativamente superior frente a modelos CNN entrenados desde cero
#
# La utilización de pesos preentrenados sobre ImageNet resulta especialmente efectiva para este problema debido a la similitud entre ambos dominios visuales.
#
# Este experimento demuestra cómo las arquitecturas preentrenadas permiten construir soluciones robustas incluso cuando el tamaño del dataset es limitado.

# %% [markdown]
# # **Data Augmentation**
#
# ## Objetivo
#
# En este experimento se aplican técnicas de **Data Augmentation** para incrementar artificialmente la variabilidad del dataset durante el entrenamiento.
#
# El objetivo principal es:
#
# - Mejorar la capacidad de generalización
# - Reducir el sobreajuste
# - Hacer el modelo más robusto frente a variaciones visuales
#
# Las transformaciones aplicadas incluyen:
#
# - Horizontal Flip
# - Vertical Flip
# - Random Contrast
#
# Estas operaciones se ejecutan dinámicamente durante el entrenamiento mediante capas de preprocesado de TensorFlow.

# %%
# Configuración de datasets

train_dataset = get_dataset(x_train, y_train, IMG_SIZE_BASE[:-1], BATCH_SIZE)

valid_dataset = get_dataset(x_valid, y_valid, IMG_SIZE_BASE[:-1], BATCH_SIZE)

test_dataset = get_dataset(x_test, y_test, IMG_SIZE_BASE[:-1], BATCH_SIZE)

# %%
# CNN con Data Augmentation

model = tf.keras.Sequential([

    tf.keras.layers.Input(shape=IMG_SIZE_BASE),

    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomContrast(0.2),

    tf.keras.layers.Conv2D(
        32,
        (5, 5),
        padding="same",
        activation="relu"
    ),

    tf.keras.layers.MaxPool2D(pool_size=(2, 2)),

    tf.keras.layers.Conv2D(
        64,
        (5, 5),
        padding="same",
        activation="relu"
    ),

    tf.keras.layers.MaxPool2D(pool_size=(2, 2)),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(
        1024,
        activation="relu"
    ),

    tf.keras.layers.Dense(
        len(classes),
        activation="softmax"
    )
])

# Compilación

model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 100, 120, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast                 │ (None, 100, 120, 3)    │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_99 (Conv2D)              │ (None, 100, 120, 32)   │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 50, 60, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_100 (Conv2D)             │ (None, 50, 60, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 25, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 48000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1024)           │    49,153,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 74)             │        75,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,282,570 (188.00 MB)
#  Trainable params: 49,282,570 (188.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Entrenamiento

history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS
)
# Out:
# Epoch 1/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 26s 267ms/step - accuracy: 0.0206 - loss: 4.4245 - val_accuracy: 0.0319 - val_loss: 4.2639
# Epoch 2/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 192ms/step - accuracy: 0.0511 - loss: 4.0763 - val_accuracy: 0.0732 - val_loss: 3.9878
# Epoch 3/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 24s 325ms/step - accuracy: 0.1124 - loss: 3.7223 - val_accuracy: 0.0879 - val_loss: 3.8780
# Epoch 4/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 31s 193ms/step - accuracy: 0.1881 - loss: 3.3877 - val_accuracy: 0.0905 - val_loss: 3.9055
# Epoch 5/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 22s 217ms/step - accuracy: 0.2740 - loss: 3.0090 - val_accuracy: 0.0806 - val_loss: 4.1443
# Epoch 6/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 21s 285ms/step - accuracy: 0.3749 - loss: 2.5999 - val_accuracy: 0.0879 - val_loss: 4.2336
# Epoch 7/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 18s 246ms/step - accuracy: 0.4874 - loss: 2.1323 - val_accuracy: 0.0956 - val_loss: 4.5233
# Epoch 8/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 21s 286ms/step - accuracy: 0.5962 - loss: 1.7065 - val_accuracy: 0.0888 - val_loss: 4.7178
# Epoch 9/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 34s 194ms/step - accuracy: 0.7054 - loss: 1.2666 - val_accuracy: 0.0853 - val_loss: 4.9512
# Epoch 10/10
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 14s 197ms/step - accuracy: 0.7845 - loss: 0.9348 - val_accuracy: 0.0737 - val_loss: 5.4981

# %%
# Evaluación

test_loss, test_accuracy = model.evaluate(test_dataset)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.0806 - loss: 5.3325
# Test Loss: 5.3325
# Test Accuracy: 0.0806

# %% [markdown]
# ## Resultados
#
# La estrategia de Data Augmentation consigue una ligera mejora en generalización respecto al modelo CNN base.
#
# Sin embargo, el impacto sigue siendo limitado frente al rendimiento obtenido mediante Transfer Learning.
#
# ### Observaciones
#
# - El sobreajuste sigue presente
# - El entrenamiento es más estable
# - Algunas transformaciones no aportan mejoras relevantes
# - El `vertical flip` puede introducir ejemplos poco realistas para este caso de uso
#
# Posibles líneas futuras de mejora:
#
# - Rotaciones suaves
# - Ajustes de brillo
# - Gaussian Noise
# - Random Zoom
# - Combinación con Dropout

# %% [markdown]
# # **Conclusiones**
#
# ## Comparativa de experimentos
#
# A lo largo del proyecto se han evaluado múltiples enfoques para clasificación de razas de perros:
#
# | Modelo | Resultado |
# |---|---|
# | CNN básica | Bajo rendimiento y sobreajuste |
# | CNN + Dropout | Mejora parcial |
# | CNN + Data Augmentation | Generalización moderadamente mejor |
# | InceptionV3 Transfer Learning | Mejor rendimiento global |
#
# ---
#
# ## Modelo recomendado para producción
#
# El modelo basado en **InceptionV3 + Transfer Learning** sería la opción elegida para un entorno productivo.
#
# ### Motivos principales
#
# - Mayor accuracy en validación y test
# - Mejor capacidad de generalización
# - Entrenamiento más estable
# - Menor sobreajuste
# - Excelente relación rendimiento/coste computacional
#
# Además, Transfer Learning demuestra ser una estrategia altamente eficiente cuando se dispone de datasets de tamaño medio y problemas similares a ImageNet.

# %% [markdown]
# ---
#
# # Próximas mejoras
#
# Posibles líneas futuras para evolucionar el proyecto:
#
# - Fine-Tuning parcial desbloqueando capas superiores
# - Aumento del dataset
# - Experimentación con EfficientNet o ConvNeXt
# - Exportación del modelo a TensorFlow Lite
# - Despliegue mediante API REST o Streamlit
# - Monitorización de inferencia en producción
#
# ---

# %% [markdown]
# ## Limitaciones
#
# - Dataset relativamente pequeño para algunas razas
# - Algunas clases presentan similitud visual elevada
# - El modelo no ha sido optimizado para inferencia en tiempo real
# - No se ha realizado fine-tuning parcial de capas superiores

# %% [markdown]
# Nota:
# Debido a incompatibilidades entre versiones recientes de Keras y AutoKeras en Google Colab, la sección de Autokeras ha sido eliminada ya que puede requerir versiones específicas de TensorFlow/Keras.
